# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from google.colab import drive
drive.mount('/content/drive',force_remount=True)

pic = Image.open('/content/drive/MyDrive/Test/TestImg.jpg') #Выгружаем изображение
pic_arr = np.asarray(pic) #Переводим объект класса Image в объект класса Множества
plt.imshow(pic_arr) #Отобразить изображение
# Out:
# Mounted at /content/drive

# %%
c_pic = pic_arr.copy() #копия изображения

# R G B - вытаскиваем каналы и сохраняем в переменные
#Последний индекс - это каналы, а две предыдущие размеры матриц
red = c_pic[:,:,0]
green = c_pic[:,:,1]
blue = c_pic[:,:,2]

"""
 Здесь, когда мы хотим рассмотреть картинку, исходя из одного канала,
 мы увидим необычный цвет, который библиотка сама по умолчанию выбирает
 По факту, в двумерной матрице есть только оттенки серого, никак иначе
"""
# plt.imshow(red) #Отобразить изображение
# plt.imshow(green) #Отобразить изображение
# plt.imshow(blue) #Отобразить изображение

"""
  Здесь мы меняем умолчание в серый цвет
"""
# plt.imshow(red, 'gray') #Отобразить изображение
# plt.imshow(green, 'gray') #Отобразить изображение
# plt.imshow(blue, 'gray') #Отобразить изображение
# Out:
# '\n  Здесь мы меняем умолчание в серый цвет\n'

# %%
"""
  Рассмотрим прямо отдельный оттенок красного из канала 0
  Т.е. все каналы зануляем
"""
# red_pic = c_pic.copy()
# red_pic[:,:,1] = 0
# red_pic[:,:,2] = 0
# plt.imshow(red_pic) #Отобразить изображение

# green_pic = c_pic.copy()
# green_pic[:,:,0] = 0
# green_pic[:,:,2] = 0
# plt.imshow(green_pic) #Отобразить изображение

# blue_pic = c_pic.copy()
# blue_pic[:,:,0] = 0
# blue_pic[:,:,1] = 0
# plt.imshow(blue_pic) #Отобразить изображение

green_pic = c_pic.copy()
green_pic[0:220,0:250,0] = 0
green_pic[0:400,0:400,2] = 0
plt.imshow(green_pic) #Отобразить изображение
